# %%
test_numbers = [
    -10, -1, 0, 1, 2, 3, 4, 5, 6, 7, 9, 11, 13, 15, 17, 19, 21, 25, 27, 47, 49, 79, 97, 100, 523, 527, 1000, 7919, 10000, 104729, 1000000
]

def prime(n):
    count = 0

    for i in range(1, n + 1):
        if n % i == 0:
            count =count + 1

    return count == 2

result = list(filter(prime, test_numbers))

print(result)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19, 47, 79, 97, 523, 7919, 104729]

# %% [markdown]
# ATM Withdraw with Exception
# total_amount = 2560
#
# def get_cash(withdraw_amt):

# %%
total_amount = 2560

def get_cash(withdraw_amount):
    global total_amount

    if withdraw_amount > total_amount:
        raise Exception("Insufficient balance")

    total_amount -= withdraw_amount
    return withdraw_amount


try:
    amount = int(input("Enter amount: "))
    print("Cash withdrawn:", get_cash(amount))
    print("Remaining balance:", total_amount)

except Exception as e:
    print(e)
# Out:
# Cash withdrawn: 200
# Remaining balance: 2360
