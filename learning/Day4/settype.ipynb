# %% [markdown]
# Python Set Type
# A set is an unordered collection of unique elements in Python. Sets are mutable, meaning their contents can be changed after they are created. Sets are created using curly braces {} or the set() constructor.
#
# Creating a Set
# To create a set, you can use curly braces {} with comma-separated values inside or the set() constructor with a list as an argument. Here are some examples:

# %%
setA = {4, 5, 8, 1, 1, 1, 2, 3}
type(setA)
# Out:
# set

# %%
setA = {4, 5, 8, 1, 1, 1, 2, 3}
type(setA)
# Out:
# set

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
set(["mississipi","lossantos"])
# Out:
# {'lossantos', 'mississipi'}

# %%
set("mississipi")
# Out:
# {'i', 'm', 'p', 's'}

# %% [markdown]
# Set Modification

# %%
setA
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
setA.add(9)
setA
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
setA.update([4,0,12])
setA
# Out:
# {0, 1, 2, 3, 4, 5, 8, 9, 12}

# %%
setA.add("CLASS")
setA
# Out:
# {0, 1, 12, 2, 3, 4, 5, 8, 9, 'CLASS'}

# %%
setA.pop()
setA
# Out:
# {1, 12, 2, 3, 4, 5, 8, 9, 'CLASS'}

# %%
setA.remove("CLASS")
setA
# Out:
# {1, 2, 3, 4, 5, 8, 9, 12}

# %%
setA.discard(5)
setA
# Out:
# {1, 2, 3, 4, 8, 9, 12}

# %% [markdown]
# Set Operations
# Docs : https://www.w3schools.com/python/python_ref_set.asp
#
# Sets in Python support a variety of operations, including union, intersection, difference, and symmetric difference. Here are some examples:

# %%
a = {1,2,3,4,5}
b = {3,5,7,9,11}
aUb = a.union(b) # a | b | c | d 
aUb
# Out:
# {1, 2, 3, 4, 5, 7, 9, 11}

# %%
aNb = a.intersection(b) # a & b
aNb
# Out:
# {3, 5}

# %%
b_a = b.difference(a) # b - a
b_a
# Out:
# {7, 9, 11}

# %%
a.symmetric_difference(b) # a^b
# Out:
# {1, 2, 4, 7, 9, 11}

# %%
A = {1,2,3,4,5,6,7,8,9}
B = {5,6,7,8}
A.issubset(B) # A <= B
# Out:
# False

# %%
B.issubset(A) # B <= A
# Out:
# True

# %%
A.issuperset(B) # A >= B
# Out:
# True

# %%
B < A # proper Subset
# Out:
# True

# %%
B.isdisjoint(A)
# Out:
# False
